# %% [markdown]
# # aws ubuntu server virtualenv 환경설정

# %% [markdown]
# $ ssh -i ~/.ssh/wps.pem ubuntu@255.255.255.255

# %% [markdown]
# $ curl -L https://raw.githubusercontent.com/yyuu/pyenv-installer/master/bin/pyenv-installer | bash

# %%
from IPython.display import Image
Image('./curl_pyenv_install.png')

# %% [markdown]
# # Load pyenv automatically by adding
# # the following to ~/.bash_profile:
#
# - vi ~/.bashrc
# - sudo vi ~/.bashrc

# %%
# bashrc add text
Image('./bashrc_add_text.png')

# %% [markdown]
# ### pyenv 존재하는지 확인
# pyenv 입력

# %%
Image('./pyenv_check_exist.png')

# %%
# sudo apt-get install -y make build-essential libssl-dev zlib1g-dev libbz2-dev \
# libreadline-dev libsqlite3-dev wget curl llvm libncurses5-dev libncursesw5-dev \
# xz-utils tk-dev libffi-dev liblzma-dev python-openssl git

# %%
Image('./pyenv_setting_libraries.png')

# %% [markdown]
# pyenv install --list
# - pyenv install --list

# %% [markdown]
# ### pyenv versions 확인

# %%
Image('pyenv20191210.png')

# %% [markdown]
#  이후 원하는 버전을 설치한다.
# - pyenv install 3.7.5

# %%
Image('./pyenv_install_3.7.5.png')

# %% [markdown]
# ### pyenv로 관리되는 파이썬 목록 확인
# ### 전역에서 사용할 파이썬 설정
# - pyenv global 3.7.5 설정하기
# - pyenv versions

# %%
Image('./pyenv_global.png')

# %% [markdown]
# # 3.7.4버전을 기준으로 sample-env라는 환경을 만듭니다.
# ➜ pyenv virtualenv 3.7.4 sample-env
# - (생성하면서 Requirement already....라는 메시지가 출력됩니다)

# %%
Image('./pyenv_virtual_create.png')

# %% [markdown]
# ~/projects/sample-project ➜ pyenv local sample-env
# ### 프롬프트 좌측에 적용된 가상환경명이 표시됩니다

# %%
Image('./pyenv_local_env_connection.png')
